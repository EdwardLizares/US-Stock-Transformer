# %%
from stock_gpt import StockGPT
from setup import Stock_GPT_cfg

# %%
model = StockGPT(Stock_GPT_cfg)
total_params = sum(p.numel() for p in model.parameters())
print(total_params)
# Out:
# 13312

# %% [markdown]
# ### Attention Matrix

# %%
trie
